# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re
client_id = ""
client_secret = ""
# encText = urllib.parse.quote("검색할 단어")
query = urllib.parse.quote(input('검색 질의: '))

idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('Title','Link','Description'))

for s_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
    +"&display" + str(display) \
    +"&start=" + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.docode('utf-8'))
        item = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '',items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx += 1
    else:
        print("Error Code:" + rescode)
web_df

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = ""
client_secret = ""
# encText = urllib.parse.quote("빅데이터")
query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('Title','Link','Description'))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx += 1        
    else:
        print("Error Code:" + rescode)
web_df
# Out:
#                                        Title  \
# 0                                빅데이터학과 입시정보
# 1                          빅데이터학원 기초과정부터 배워요
# 2             빅데이터분석기사인강 통한 시험 준비로 필기 합격 기대!
# 3                           빅데이터학원 실기 위주의 학습
# 4                     빅데이터전문가자격증 공부 순서는 이렇게!
# ..                                       ...
# 995                      [bOOk] 통계학 빅데이터를 잡다
# 996  램지를 뛰어넘는 컨설턴트&quot; - 빅데이터, 4차 산업혁명의 언어
# 997        택배 주문 밀키트 구매 연락처 수도권 최고의 빅데이터랭킹맛집
# 998        부동산빅데이터를  활용한 아파트  시장분석에 대해 배웠습니다
# 999   [주식News] 언어 빅데이터를 다루는 플리토, 한국판 뉴딜로...
#
#                                                   Link  \
# 0    https://blog.naver.com/myhanayou?Redirect=Log&...
# 1    https://blog.naver.com/ssohi07?Redirect=Log&lo...
# 2    https://blog.naver.com/waiting25?Redirect=Log&...
# 3    https://blog.naver.com/blackhole68?Redirect=Lo...
# 4    https://blog.naver.com/eshan97?Redirect=Log&lo...
# ..                                                 ...
# ...

# %%
# [과제] 뉴스, 책, 쇼핑, 영화, 지식IN중에서 2개 이상의 카테고리를 선택하여 관심 주제에 대한 데이터를 1000개까지 출력하세요.
# [과제] 2개 이상의 카테고리에 대하여 데이터 수집

# %%
# 뉴스
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = ""
client_secret = ""
query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'

news_df = pd.DataFrame(columns=('Title','Link','Description','PubDate'))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/news?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&sort=" +sort
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            remove_tag2 = re.compile('&.*?;')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            title = re.sub(remove_tag2, "", title)
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pubdate = items[item_index]['pubDate']
            news_df.loc[idx] = [title, link, description,pubdate]
            idx += 1        
    else:
        print("Error Code:" + rescode)
news_df
# Out:
#                                                  Title  \
# 0                       [올림픽] 폭설에 베이징 성화 꺼진 듯USA투데이스포츠
# 1                                [올림픽] 폭설에 베이징 성화 꺼진 듯
# 2                       ‘가장 소박한 성화’ 꺼졌나…폭설에 베이징올림픽 차질?
# 3                        폭설로 베이징 동계올림픽 성화 꺼진 듯…美 언론 보도
# 4               [올림픽] 무서운 뒤집기…쇼트트랙 황대헌, 남자 500m 준결승 진출
# ..                                                 ...
# 995  '러 피겨 女王 금지약물 사실로' IOC 공식 발표, 출전 여부는 CAS에서[베이징...
# 996                                  [올림픽] 김준호의 힘찬 레이스
# 997                               [올림픽] 차민규, 2회 연속 은메달
# 998                                [올림픽] 김준호, 직선 주로 역주
# 999                                    [올림픽] 손 흔드는 차민규
#
#                                                   Link  \
# 0    https://news.naver.com/main/read.naver?mode=LS...
# 1    https://news.naver.com/main/read.naver?mode=LS...
# 2    https://news.naver.com/main/read.naver?mode=LS...
# 3    https://news.naver.com/main/read.naver?mode=LS...
# ...

# %%
# 뉴스
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = ""
client_secret = ""
query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'

news_df = pd.DataFrame(columns=('Title','Link','Lprice','Brand'))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/shop?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&sort=" +sort
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            # remove_tag2 = re.compile('&.*?;')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            # title = re.sub(remove_tag2, "", title)
            link = items[item_index]['link']
            lprice = items[item_index]['lprice']
            brand = items[item_index]['brand']
            news_df.loc[idx] = [title, link, lprice,brand]
            idx += 1        
    else:
        print("Error Code:" + rescode)
news_df
# Out:
#                                         Title  \
# 0                   GALAX 지포스 RTX 3050 D6 8GB
# 1     이엠텍 지포스 RTX 3050 STORM X Dual OC D6 8GB
# 2       MSI 지포스 RTX 3060 게이밍 X D6 12GB 트윈프로져8
# 3    기가바이트 지포스 RTX 3050 Gaming OC D6 8GB 제이씨현
# 4                   MSI 라데온 RX 6600 아머 D6 8GB
# ..                                        ...
# 995                    RX5600 8GB hbm2 그래픽 카드
# 996                            FQ 데스크탑 그래픽 카드
# 997                그래픽 카드 4G DDR5 데스크탑 그래픽 카드
# 998                구매 gtx 1060 6gb 그래픽 카드 온라인
# 999      AMD FirePro W5100 그래픽 카드   4GB - AMD
#
#                                                   Link   Lprice  Brand
# 0    https://search.shopping.naver.com/gate.nhn?id=...   484390  GALAX
# 1    https://search.shopping.naver.com/gate.nhn?id=...   524400    이엠텍
# 2    https://search.shopping.naver.com/gate.nhn?id=...   899000    MSI
# 3    https://search.shopping.naver.com/gate.nhn?id=...   538500  기가바이트
# ...

# %% [markdown]
# [과제]
# 아래 사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
#
# - https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# - 개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
# - New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# - 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
# - 서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
#     - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#     - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#     - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# - json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)
#
# - 도시 = Seoul | 날씨 = broken clouds | 최저 기온 = -1.0 2 | 최고 기온 = 2.0 2 | 습도 = 74 | 기압 = 1023 | 풍속 = 0.5

# %%
"""
+ 도시 = Seoul
| 날씨 = clear sky
| 최저 기온 = -4.0 2
| 최고 기온 = -0.0 2
| 습도 = 70
| 기압 = 1024
| 풍속 = 2.06

+ 도시 = Tokyo
| 날씨 = mist
| 최저 기온 = -0.0 2
| 최고 기온 = 3.0 2
| 습도 = 95
| 기압 = 1016
| 풍속 = 9.26

+ 도시 = New York
| 날씨 = few clouds
| 최저 기온 = -1.0 2
| 최고 기온 = 4.0 2
| 습도 = 86
| 기압 = 1011
| 풍속 = 1.54
"""

# %%
import requests
import json


city = 'Seoul'
apikey = ''
units = 'metric'
lang = 'kr'

url = 'http://api.openweathermap.org/data/2.5/weather?q=' + city + '&APPID=' + apikey + '&units=' + units
res = requests.get(url).text
res_dict = json.loads(res)
res_dict
# Out:
# {'coord': {'lon': 126.9778, 'lat': 37.5683},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 273.64,
#   'feels_like': 270.16,
#   'temp_min': 270.88,
#   'temp_max': 275.84,
#   'pressure': 1022,
#   'humidity': 74},
#  'visibility': 10000,
#  'wind': {'speed': 3.09, 'deg': 310},
#  'clouds': {'all': 0},
#  'dt': 1644761939,
#  'sys': {'type': 1,
#   'id': 8105,
#   'country': 'KR',
#   'sunrise': 1644704674,
#   'sunset': 1644743295},
#  'timezone': 32400,
#  'id': 1835848,
#  'name': 'Seoul',
#  'cod': 200}

# %%
import requests
import json
import numpy as np

cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
apikey = ""
units = "metric"
weather_df = pd.DataFrame(columns=('도시','날씨','최저기온(도씨)','최고기온(도씨)','습도(%)','기압(hPa)','풍향(도)','풍속(m/s)'))
for i in range(len(cities)):
    url = "http://api.openweathermap.org/data/2.5/weather?q=" + cities[i] + '&APPID=' + apikey + '&units=' + units
    res = requests.get(url).text
    res_dict = json.loads(res)
    new_data = {'도시' : res_dict['name'],
                '날씨' : res_dict['weather'][0]['description'],
                '최저기온(도씨)' : np.round(res_dict['main']['temp_min'],1),
                '최고기온(도씨)' : np.round(res_dict['main']['temp_max'],1),
                '습도(%)' : res_dict['main']['humidity'],
                '기압(hPa)' : res_dict['main']['pressure'],
                '풍향(도)' : res_dict['wind']['deg'],
                '풍속(m/s)' : np.round(res_dict['wind']['speed'],1)}
    weather_df = weather_df.append(new_data,ignore_index=True)
weather_df = weather_df.set_index('도시')
weather_df
# Out:
#                   날씨  최저기온(도씨)  최고기온(도씨) 습도(%) 기압(hPa) 풍향(도)  풍속(m/s)
# 도시
# Seoul      clear sky      -2.8       2.7    59    1022    28      1.4
# Tokyo     light snow      -0.3       3.1    95    1018    10      8.2
# New York        snow      -1.8       1.4    89    1022    60      4.6

# %%
# 선생님의 form으로..
import requests
import json
import numpy as np

apikey =""
cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
units = "metric"

for name in cities:
    url = "http://api.openweathermap.org/data/2.5/weather?q=" + name + '&APPID=' + apikey + '&units=' + units
    res = requests.get(url).text
    df = json.loads(res)

# 결과 출력하기
    print("+ 도시 =", df["name"])
    print("| 날씨 =", df["weather"][0]["description"])
    print("| 최저 기온 =", np.round(df["main"]["temp_min"],1))
    print("| 최고 기온 =", np.round(df["main"]["temp_max"],1))
    print("| 습도 =", df["main"]["humidity"])
    print("| 기압 =", df["main"]["pressure"])
    print("| 풍향 =", df["wind"]["deg"])
    print("| 풍속 =", np.round(df["wind"]["speed"],1))
    print("")
# Out:
# + 도시 = Seoul
# | 날씨 = clear sky
# | 최저 기온 = -2.8
# | 최고 기온 = 2.7
# | 습도 = 69
# | 기압 = 1022
# | 풍향 = 330
# | 풍속 = 3.1
#
# + 도시 = Tokyo
# | 날씨 = snow
# | 최저 기온 = -0.3
# | 최고 기온 = 3.1
# | 습도 = 95
# | 기압 = 1018
# | 풍향 = 360
# | 풍속 = 8.8
#
# + 도시 = New York
# | 날씨 = snow
# | 최저 기온 = -1.6
# | 최고 기온 = 1.5
# | 습도 = 89
# | 기압 = 1022
# | 풍향 = 20
# | 풍속 = 4.6

# %%
# [팀과제] 관심 주제에 대한 사이트 API 학습 및 실사례 소개

# %%
# !pip install google-api-python-client
# conda install -c conda-forge google-api-python-client
import pandas as pd
from googleapiclient.discovery import build
# 성시경의 킬링보이스
# https://www.youtube.com/watch?v=6RQ-bBdASvk
 
api_key = ''
video_id = '6RQ-bBdASvk'
 
# build로 Google Api 객체 생성 및 객체 호출 >> 전달 받은 데이터가 저장
comments = []
api_obj = build('youtube', 'v3', developerKey=api_key)
response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, maxResults=100).execute()
response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'MQR2oquZg_b3LVc6YWtSJSCcpLM',
#  'nextPageToken': 'QURTSl9pMGwxLU81R3Y5RmZfSU9hRDd0NEI5MllCVVNJR3FhU3dubkJyMzg4VmpIRjFVaDdtMlhYQTVEMUlIc0t5Q2hKNUV0OTBhYlZyek80STRrOWc=',
#  'pageInfo': {'totalResults': 100, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'DPET0VqRMSmhsHsHXcti7iBCFK4',
#    'id': 'Ugye7uR8z22uDPWemc94AaABAg',
#    'snippet': {'videoId': '6RQ-bBdASvk',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'JFao2h17kJSJVwRqq5lGhoaYdRo',
#      'id': 'Ugye7uR8z22uDPWemc94AaABAg',
#      'snippet': {'videoId': '6RQ-bBdASvk',
#       'textDisplay': '&#39;너의 모든 순간&#39; 들으니까<br>별에서 온 그대 드라마가 그냥 파노라마로 지나가네',
#       'textOriginal': "'너의 모든 순간' 들으니까\n별에서 온 그대 드라마가 그냥 파노라마로 지나가네",
#       'authorDisplayName': '가버렷',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLREYov2Y-wdpCTGZ280pIcJ7Ke9SwJXgHPKnw=s48-c-k-c0x00ffffff-no-rj',
# ...

# %%
len(response['items'])
# Out:
# 100

# %%
# 유튜브 API 참고 : https://developers.google.com/youtube/v3/docs
# !pip install google-api-python-client
# conda install -c conda-forge google-api-python-client
import pandas as pd
from googleapiclient.discovery import build
# 성시경의 킬링보이스
# https://www.youtube.com/watch?v=6RQ-bBdASvk
 
api_key = ''
video_id = '6RQ-bBdASvk'
 
# build로 Google Api 객체 생성 및 객체 호출 >> 전달 받은 데이터가 저장
comments = []
api_obj = build('youtube', 'v3', developerKey=api_key)
# commentThreads().list -> 원하는 요소만 보고 싶을 때 (id, snippet, replies)
# maxresult -> 'items' 개수
response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, maxResults=100).execute()

# 수집할 항목이 있는 것을 뽑아
while response:
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])
        # 대댓글이 있는 경우 같이 수집
        if item['snippet']['totalReplyCount'] > 0:
            for reply_item in item['replies']['comments']:
                reply = reply_item['snippet']
                comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
    # 댓글이 더 있는 경우 nextPageToken 이용해 API 다시 호출
    if 'nextPageToken' in response:
        response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, pageToken=response['nextPageToken'], maxResults=100).execute()
    else:
        break
# 수집한 데이터를 데이터프레임으로 구성
df = pd.DataFrame(comments)
df.to_excel('results.xlsx', header=['comment', 'author', 'date', 'num_likes'], index=None)

# %%
df = pd.read_excel('./results.xlsx')
df.sort_values(by='num_likes', ascending=False).head()
# Out:
#                                                  comment               author  \
# 13736          약700만뷰 중에 5번이상은 자신이 들었다면 시끄럽게 손 한번만 들어주세요                  홍성화
# 21906                                       시경이형 나랑 결혼하자    장성규니버스 K-universe
# 32491  진짜 전체적인 곡을 듣는것도 좋지만.. 히트곡이 많은 가수일수록 킬링 보이스 값을 ...            뜐뜐 tuntun
# 27740                        코로나 끝나면.. 제일 가고 싶은 이윽고콘서트..   thanks for coming.
# 32358  🎧감미로운 목소리의 대명사, 성발라의 선곡 리스트 🎧<br><br><a href="...  딩고 뮤직 / dingo music
#
#                        date  num_likes
# 13736  2021-06-12T15:34:52Z      30237
# 21906  2021-05-28T06:47:37Z      17502
# 32491  2021-05-25T10:09:29Z      15114
# 27740  2021-05-26T01:41:37Z      14872
# 32358  2021-05-25T10:28:07Z      13546

# %% [markdown]
# 포털 댓글 감성 분석: https://projectlog-eraser.tistory.com/27
# 워드 클라우드: http://wordcloud.kr/
# LDA 토픽 모델: https://ratsgo.github.io/from%20frequency%20to%20semantics/2017/06/01/LDA/
#     - LDA에서는 나머지 변수는 고정시킨 채 한 변수만을 변화시키되, 불필요한 일부 변수를 샘플링에서 제외하는 collapsed gibbs sampling 기법
